# %% [markdown]
# # Introduction
#
# This notebook is from [Cervix segmentation (GMM) | Kaggle Discussion](https://www.kaggle.com/chattob/cervix-segmentation-gmm/comments/notebook).
#
# But I modified some parts to make it easier use.
#
# This kernels aims at segmenting the cervix using the technique presented in this paper: https://www.researchgate.net/publication/24041301_Automatic_Detection_of_Anatomical_Landmarks_in_Uterine_Cervix_Images
#
# ## 1. Basic Operation for Reading Image data
#
# This part shows you how to read image. Of course, this part has been writen as functions.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import cv2
import math
from sklearn import mixture
from sklearn.utils import shuffle
from skimage import measure
from glob import glob
import os
from multiprocessing import Pool, cpu_count
from functools import partial
from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))
print(check_output(["ls", "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/"]).decode("utf8"))


def get_filename(image_id, image_type):
    """
    Method to get image file path from its id and type   
    """
    if image_type == "Type_1" or \
        image_type == "Type_2" or \
        image_type == "Type_3":
        data_path = os.path.join(TRAIN_DATA, image_type)
    elif image_type == "test" or "test_stg2":
        data_path = TEST_DATA
    elif image_type == "AType_1" or \
          image_type == "AType_2" or \
          image_type == "AType_3":
        data_path = os.path.join(ADDITIONAL_DATA, image_type)
    else:
        raise Exception("Image type '%s' is not recognized" % image_type)

    ext = 'jpg'
    return os.path.join(data_path, "{}.{}".format(image_id, ext))

def get_image_data(image_id, image_type):
    """
    获取图像以numpy数组的形式，即np.array同时指定确定每张图像的id和类型
    """
    fname = get_filename(image_id, image_type)
    img = cv2.imread(fname)
    print "get_image_data:"+fname
    assert img is not None, "Failed to read /image : %s, %s" % (image_id, image_type)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img
# Out:
# additional_Type_1_v2.7z
# additional_Type_2_v2.7z
# additional_Type_3_v2.7z
# Cervix_types_clasification.pdf
# cp_rename_for_same_name_file.sh
# others
# sample_submission.csv
# sample_submission.csv.zip
# sample_submission_stg2.csv
# sample_submission_stg2.csv.zip
# solution_stg1_release.csv.zip
# test
# test.7z
# test_seg_224.zip
# test_stg2
# test_stg2.7z
# test_stg2.7z.td
# test_stg2.7z.td.cfg
# test_stg2_password.txt
# test_stg2_password.txt~
# train
# train.7z
# train_add
# train_add_seg_224
# train_add_seg_224.zip
# train_seg_224
# train_seg_224.zip
# train_tmp
# Type_1
# Type_2
# Type_3

# %% [markdown]
# ## 2. Remove Circular Frame
#
# First, we crop the image in order to remove the circular frames that might be present. This is done by finding the largest inscribed rectangle to the thresholded image. The image is then cropped to this rectangle. (see these videos for an explanation of the algorithm: https://www.youtube.com/watch?v=g8bSdXCG-lA, https://www.youtube.com/watch?v=VNbkzsnllsU)

# %%
def maxHist(hist):
    maxArea = (0, 0, 0)
    height = []
    position = []
    for i in range(len(hist)):
        if (len(height) == 0):
            if (hist[i] > 0):
                height.append(hist[i])
                position.append(i)
        else: 
            if (hist[i] > height[-1]):
                height.append(hist[i])
                position.append(i)
            elif (hist[i] < height[-1]):
                while (height[-1] > hist[i]):
                    maxHeight = height.pop()
                    area = maxHeight * (i-position[-1])
                    if (area > maxArea[0]):
                        maxArea = (area, position[-1], i)
                    last_position = position.pop()
                    if (len(height) == 0):
                        break
                position.append(last_position)
                if (len(height) == 0):
                    height.append(hist[i])
                elif(height[-1] < hist[i]):
                    height.append(hist[i])
                else:
                    position.pop()    
    while (len(height) > 0):
        maxHeight = height.pop()
        last_position = position.pop()
        area =  maxHeight * (len(hist) - last_position)
        if (area > maxArea[0]):
            maxArea = (area, len(hist), last_position)
    return maxArea
            

def maxRect(img):
    maxArea = (0, 0, 0)
    addMat = np.zeros(img.shape)
    for r in range(img.shape[0]):
        if r == 0:
            addMat[r] = img[r]
            area = maxHist(addMat[r])
            if area[0] > maxArea[0]:
                maxArea = area + (r,)
        else:
            addMat[r] = img[r] + addMat[r-1]
            addMat[r][img[r] == 0] *= 0
            area = maxHist(addMat[r])
            if area[0] > maxArea[0]:
                maxArea = area + (r,)
    return (int(maxArea[3]+1-maxArea[0]/abs(maxArea[1]-maxArea[2])), maxArea[2], maxArea[3], maxArea[1], maxArea[0])

def cropCircle(img):
    if(img.shape[0] > img.shape[1]):
        tile_size = (int(img.shape[1]*256/img.shape[0]),256)
    else:
        tile_size = (256, int(img.shape[0]*256/img.shape[1]))

    img = cv2.resize(img, dsize=tile_size)
            
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY);
    _, thresh = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)

    _, contours, _ = cv2.findContours(thresh.copy(),cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)

    main_contour = sorted(contours, key = cv2.contourArea, reverse = True)[0]
            
    ff = np.zeros((gray.shape[0],gray.shape[1]), 'uint8') 
    cv2.drawContours(ff, main_contour, -1, 1, 15)
    ff_mask = np.zeros((gray.shape[0]+2,gray.shape[1]+2), 'uint8')
    cv2.floodFill(ff, ff_mask, (int(gray.shape[1]/2), int(gray.shape[0]/2)), 1)
    
    rect = maxRect(ff)
    rectangle = [min(rect[0],rect[2]), max(rect[0],rect[2]), min(rect[1],rect[3]), max(rect[1],rect[3])]
    img_crop = img[rectangle[0]:rectangle[1], rectangle[2]:rectangle[3]]
    cv2.rectangle(ff,(min(rect[1],rect[3]),min(rect[0],rect[2])),(max(rect[1],rect[3]),max(rect[0],rect[2])),3,2)
    
    return [img_crop, rectangle, tile_size]

# %% [markdown]
# ## 3. Finding Image Center Using Color and Continuous Regions
#
# “For an initial delineation of the cervix, we use two features:
#
# * the a color channel of the source image in Lab color space (the higher the value of a , the “redder” the pixel color)
# * R, the distance of a pixel from the image center. The R feature provides spatial information and supports the extraction of continuous regions within the image plane."

# %%
def Ra_space(img, Ra_ratio, a_threshold):
    imgLab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB);
    w = img.shape[0]
    h = img.shape[1]
    Ra = np.zeros((w*h, 2))
    for i in range(w):
        for j in range(h):
            R = math.sqrt((w/2-i)*(w/2-i) + (h/2-j)*(h/2-j))
            Ra[i*h+j, 0] = R
            Ra[i*h+j, 1] = min(imgLab[i][j][1], a_threshold)
            
    Ra[:,0] /= max(Ra[:,0])
    Ra[:,0] *= Ra_ratio
    Ra[:,1] /= max(Ra[:,1])

    return Ra

# %% [markdown]
# ## 4. Separating Image in New feature Space
#
# "The image is separated next into two clusters in the 2-D (a-R) feature space; we use Gaussian mixture modeling, initialized by a K-means procedure."

# %%
def get_and_crop_image(image_id, image_type):
    img = get_image_data(image_id, image_type)
    initial_shape = img.shape
    [img, rectangle_cropCircle, tile_size] = cropCircle(img)
    imgLab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB);
    w = img.shape[0]
    h = img.shape[1]
    Ra = Ra_space(imgLab, 1.0, 150)
    a_channel = np.reshape(Ra[:,1], (w,h))
    
    g = mixture.GaussianMixture(n_components = 2, covariance_type = 'diag', random_state = 0, init_params = 'kmeans')
    image_array_sample = shuffle(Ra, random_state=0)[:1000]
    g.fit(image_array_sample)
    labels = g.predict(Ra)
    labels += 1 # Add 1 to avoid labeling as 0 since regionprops ignores the 0-label.
    
    # The cluster that has the highest a-mean is selected.
    labels_2D = np.reshape(labels, (w,h))
    gg_labels_regions = measure.regionprops(labels_2D, intensity_image = a_channel)
    gg_intensity = [prop.mean_intensity for prop in gg_labels_regions]
    cervix_cluster = gg_intensity.index(max(gg_intensity)) + 1

    mask = np.zeros((w * h,1),'uint8')
    mask[labels==cervix_cluster] = 255
    mask_2D = np.reshape(mask, (w,h))

    cc_labels = measure.label(mask_2D, background=0)
    regions = measure.regionprops(cc_labels)
    areas = [prop.area for prop in regions]

    regions_label = [prop.label for prop in regions]
    largestCC_label = regions_label[areas.index(max(areas))]
    mask_largestCC = np.zeros((w,h),'uint8')
    mask_largestCC[cc_labels==largestCC_label] = 255

    img_masked = img.copy()
    img_masked[mask_largestCC==0] = (0,0,0)
    img_masked_gray = cv2.cvtColor(img_masked, cv2.COLOR_RGB2GRAY);
            
    _,thresh_mask = cv2.threshold(img_masked_gray,0,255,0)
            
    kernel = np.ones((11,11), np.uint8)
    thresh_mask = cv2.dilate(thresh_mask, kernel, iterations = 1)
    thresh_mask = cv2.erode(thresh_mask, kernel, iterations = 2)
    _, contours_mask, _ = cv2.findContours(thresh_mask.copy(),cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)

    main_contour = sorted(contours_mask, key = cv2.contourArea, reverse = True)[0]
    cv2.drawContours(img, main_contour, -1, 255, 3)
    
    x,y,w,h = cv2.boundingRect(main_contour)
    
    rectangle = [x+rectangle_cropCircle[2],
                 y+rectangle_cropCircle[0],
                 w,
                 h,
                 initial_shape[0],
                 initial_shape[1],
                 tile_size[0],
                 tile_size[1]]

    return [image_id, img, rectangle]

# %%
def parallelize_image_cropping(image_ids, img_save_base_dir, types, resize_shape=(224, 224)):
    # 新建文件并将crop在原图的位置保存
    out = open('rectangles.csv', "w")
    out.write("image_id,type,x,y,w,h,img_shp_0_init,img_shape1_init,img_shp_0,img_shp_1\n")
    imf_d = {}
    # 利用多线程(python的multiprocessing库)来执行
    p = Pool(cpu_count())
    for type in enumerate(types):
        partial_get_and_crop = partial(get_and_crop_image, image_type = type[1])    
        ret = p.map(partial_get_and_crop, image_ids[type[0]])
        
        # 创建保存新图像的目录
        img_save_type_dir = img_save_base_dir+types[type[0]]+"_seg_"+str(resize_shape[0])+"/"
        if os.path.exists(img_save_type_dir):
            print "dir exists: " + img_save_type_dir
        else:
            print "prepare to create dir:" + img_save_type_dir
            os.mkdir(img_save_type_dir)
            if os.path.exists(img_save_type_dir):
                print "create successed"
            else:
                print "create failed"
                
        for i in xrange(len(ret)):
            out.write(image_ids[type[0]][i])
            out.write(',' + str(type[1]))
            out.write(',' + str(ret[i][2][0]))
            out.write(',' + str(ret[i][2][1]))
            out.write(',' + str(ret[i][2][2]))
            out.write(',' + str(ret[i][2][3]))
            out.write(',' + str(ret[i][2][4]))
            out.write(',' + str(ret[i][2][5]))
            out.write(',' + str(ret[i][2][6]))
            out.write(',' + str(ret[i][2][7]))
            out.write('\n')
            img = get_image_data(image_ids[type[0]][i], type[1])
            if(img.shape[0] > img.shape[1]):
                tile_size = (int(img.shape[1]*256/img.shape[0]), 256)
            else:
                tile_size = (256, int(img.shape[0]*256/img.shape[1]))
            img = cv2.resize(img, dsize=tile_size)
            # 注释掉画出红色框
            # 关于cv2.rectangle：Contour Features — OpenCV-Python Tutorials 1 documentation
            # http://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_contours/py_contour_features/py_contour_features.html
            # 其中两个参数是对角线坐标
            '''
            cv2.rectangle(img,
                          (ret[i][2][0], ret[i][2][1]), 
                          (ret[i][2][0]+ret[i][2][2], ret[i][2][1]+ret[i][2][3]),
                          255,
                          2)
            '''
            # 重新缩放到指定大小
            img = img[ret[i][2][1]:(ret[i][2][1]+ret[i][2][3]), ret[i][2][0]:(ret[i][2][0]+ret[i][2][2])]
            img = cv2.resize(img, dsize=resize_shape)

            # 打印图像显示
            #plt.imshow(img)            
            #plt.savefig("./"+str(i)+".jpg") # 保存的是带坐标系的图
            img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            img_save_dir = img_save_type_dir+ret[i][0]+".jpg"
            cv2.imwrite(img_save_dir, img)
            print str(i+1)+"/"+str(len(ret)), img_save_dir#,type(ret)
            #print ret[i][0]
            #plt.show()
            
        ret = []
    out.close()

    return

# %% [markdown]
# ## 5. Crop on Training Set

# %%
# plt.imshow
# ?plt.savefig

#print(check_output(["ls", "../input"]).decode("utf8"))
#print(check_output(["ls", "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/"]).decode("utf8"))

# 试验请用如下包含少量图像的目录，否则请注释掉
TRAIN_DATA = "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/train_tmp"
# 真实训练目录
#TRAIN_DATA = "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/train"

save_base_dir = TRAIN_DATA+"/"
resize_shape = (224, 224)
types = ['Type_1', 'Type_2', 'Type_3', ]
type_ids = []

for type in enumerate(types):
    type_i_files = glob(os.path.join(TRAIN_DATA, type[1], "*.jpg"))
    type_i_ids = np.array([s.split('/')[-1].split(".")[0] for s in type_i_files])
    type_ids.append(type_i_ids[:])
    print type, type_i_ids.size

# 打印检查图片是否读取成功
for idx in xrange(len(types)):
    print type_ids[idx][:10]
    print len(type_ids[idx])

# 创建用于保存分割后图像的文件夹

import os

parallelize_image_cropping(type_ids, save_base_dir, types, resize_shape=resize_shape)
    
# 检查是否创建成功
# os.listdir(save_base_dir)

# %% [markdown]
# ## 6. Crop on Test Set

# %%
# plt.imshow
# ?plt.savefig

#print(check_output(["ls", "../input"]).decode("utf8"))
#print(check_output(["ls", "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/"]).decode("utf8"))

TEST_DATA = "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test"
save_base_dir = TEST_DATA+"/"
resize_shape = (224, 224)
types = ['test']
type_ids = []

for type in enumerate(types):
    type_i_files = glob(os.path.join(TEST_DATA[:-4], type[1], "*.jpg"))
    #type_i_ids = np.array(type_i_files[len(TEST_DATA)+8:-4])
    type_i_ids = np.array([s.split('/')[-1].split(".")[0] for s in type_i_files])
    type_ids.append(type_i_ids)

print type_ids[0]    
#print type_i_files
parallelize_image_cropping(type_ids, save_base_dir, types, resize_shape=resize_shape)

# %% [markdown]
# ## 7. Crop on Train-Add Set

# %%
# plt.imshow
# ?plt.savefig

#print(check_output(["ls", "../input"]).decode("utf8"))
#print(check_output(["ls", "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/"]).decode("utf8"))

# 试验请用如下包含少量图像的目录，否则请注释掉
#TRAIN_DATA = "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/train_tmp"
# 真实训练目录
TRAIN_DATA = "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/train_add"

save_base_dir = TRAIN_DATA+"/"
resize_shape = (224, 224)
#types = ['Type_1', 'Type_2', 'Type_3', ]
types = ['Type_2', 'Type_3', ]
type_ids = []

for type in enumerate(types):
    type_i_files = glob(os.path.join(TRAIN_DATA, type[1], "*.jpg"))
    type_i_ids = np.array([s.split('/')[-1].split(".")[0] for s in type_i_files])
    type_ids.append(type_i_ids)
    print type, type_i_ids.size

# 打印检查图片是否读取成功
for idx in xrange(len(types)):
    print type_ids[idx][:10]
    print len(type_ids[idx])
print type_i_files[:10]

# 创建用于保存分割后图像的文件夹

import os

parallelize_image_cropping(type_ids, save_base_dir, types, resize_shape=resize_shape)
    
# 检查是否创建成功
# os.listdir(save_base_dir)

# %% [markdown]
# # 8. Crop on Stage2 test set

# %%
# plt.imshow
# ?plt.savefig

#print(check_output(["ls", "../input"]).decode("utf8"))
#print(check_output(["ls", "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/"]).decode("utf8"))

TEST_DATA = "/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2"
save_base_dir = TEST_DATA+"/"
resize_shape = (224, 224)
types = ['test_stg2']
type_ids = []

for type in enumerate(types):
    type_i_files = glob(os.path.join(TEST_DATA[:-len(types[0])], type[1], "*.jpg"))
    #type_i_ids = np.array(type_i_files[len(TEST_DATA)+8:-4])
    type_i_ids = np.array([s.split('/')[-1].split(".")[0] for s in type_i_files])
    type_ids.append(type_i_ids)
    #type_ids.extend(type_i_ids)

print type_ids[0]
print len(type_ids[0])
print len(type_ids)
#print type_i_files
parallelize_image_cropping(type_ids, save_base_dir, types, resize_shape=resize_shape)
# Out:
# ['10000' '10001' '10002' ..., '13503' '13504' '13505']
# 3506
# 1
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10000.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10561.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10676.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10213.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10329.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10445.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10319.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10774.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10339.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10001.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10677.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10330.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10446.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10214.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10562.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10775.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10002.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10447.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10331.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10678.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10100.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10215.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10563.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10003.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10776.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10680.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10101.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10448.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10332.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10564.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10216.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10777.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10004.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10102.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10565.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10449.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10681.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10217.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10333.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10778.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10450.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10566.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10005.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10103.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10334.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10682.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10218.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10780.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10006.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10335.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10451.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10683.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10567.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10220.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10104.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10781.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10007.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10336.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10684.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10452.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10568.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10782.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10221.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10008.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10105.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10337.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10222.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10569.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10783.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10685.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10453.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10106.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10338.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10784.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10009.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10454.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10686.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10223.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10570.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10107.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10340.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10785.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10010.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10455.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10687.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10571.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10224.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10108.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10786.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10341.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10011.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10456.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10688.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10225.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10572.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10342.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10109.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10787.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10012.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10226.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10457.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10573.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10689.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10343.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10110.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10788.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10227.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10013.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10344.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10458.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10690.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10111.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10789.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10228.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10574.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10014.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10460.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10691.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10345.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10112.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10015.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10575.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10790.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10229.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10461.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10346.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10692.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10016.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10462.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10113.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10576.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10230.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10693.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10791.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10347.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10114.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10577.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10463.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10017.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10231.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10792.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10694.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10348.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10578.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10115.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10464.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10018.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10232.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10793.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10695.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10349.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10116.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10580.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10233.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10465.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10794.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10020.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10696.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10117.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10581.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10350.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10234.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10466.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10795.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10021.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/10697.jpg
# get_image_data:/media/yuens/WIN10-ENTERTENMENT/Kaggle/Intel-CCS/test_stg2/